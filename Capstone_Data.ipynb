# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Data was found in: https://www.stats.gov.sa/ar/325

# %%
Trading_data = pd.read_excel("Trading19_.xlsx")
Trading_data.to_csv("Trading2019.csv", sep=",") 
# as seen below, this method has only used the data in the first sheet and ignored others

# %%
Trading_data
# Out:
#                                     Unnamed: 0  \
# 0                                          NaN
# 1   التجارة الخارجية\nللمملكة العربية السعودية
# 2                                          NaN
# 3                                         2019
# 4                                   رقم الجدول
# 5                                         M_AR
# 6                                            1
# 7                                          1.1
# 8                                          1.2
# 9                                          1.3
# 10                                         1.4
# 11                                         1.5
# 12                                           2
# 13                                         2.1
# 14                                         2.2
# 15                                         2.3
# 16                                         2.4
# 17                                         2.5
# 18                                         2.6
# 19                                           3
# 20                                           4
# 21                                           5
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                         العــنــوان
# 5                                            المنهجية
# 6                                    الصادرات السلعية
# 7                   الصادرات البترولية وغير البترولية
# 8                                الصادرات حسب الأقسام
# 9                          الصادرات حسب مجموعات الدول
# 10                                 الصادرات حسب الدول
# 11  الصادرات غير البترولية حسب وسيلة النقل والمناف...
# 12                                   الواردات السلعية
# 13                               الواردات حسب الأقسام
# 14                        الواردات حسب مجموعات الدول
# 15                                 الواردات حسب الدول
# 16                        الواردات حسب استخدام المواد
# 17                          الواردات حسب طبيعة المواد
# 18         الواردات حسب وسيلة النقل والمنافذ الجمركية
# 19                       حجم التجارة والميزان التجاري
# 20               نسبة الصادرات غير البترولية للواردات
# 21  التبادل التجاري بين المملكة ودول مجلس التعاون ...
#
#                                            Unnamed: 2 Unnamed: 3
# 0                                                 NaN        NaN
# 1                International trade\nof Saudi Arabia        NaN
# 2                                                 NaN        NaN
# 3                                                2019        NaN
# 4                                             Subject      Table
# 5                                         Methodology       M_EN
# 6                                 Merchandise Exports          1
# 7                             Oil and Non-oil Exports        1.1
# 8                                  Exports by Section        1.2
# 9                       Exports by Group of Countries        1.3
# 10                                 Exports by Country        1.4
# 11  Non-oil Exports by Mode of Transport and Custo...        1.5
# 12                                Merchandise Imports          2
# 13                                 Imports by Section        2.1
# 14                      Imports by Group of Countries        2.2
# 15                                 Imports by Country        2.3
# 16                    Imports by Utilization of Items        2.4
# 17                         Imports by Nature of Items        2.5
# 18      Imports by Mode of Transport and Customs Port        2.6
# 19                     Trade Volume and Trade Balance          3
# 20                Ratio of Non-oil Exports to Imports          4
# 21                       Trade with the GCC Countries          5
