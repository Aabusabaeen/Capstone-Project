# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import ggplot, aes, geom_density, geom_line, geom_point, ggtitle

# %% [markdown]
# ## Q2 Sheet 1.2
# - Exports by Section

# %%
Q2_Ex_bysection= pd.read_csv('Cleaned_data/FT_2021_Q2_1-2_clean.csv')
Q2_Ex_bysection.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q2_Ex_bysection
# Out:
#      2021_Q1_mSAR   2021_Q2_mSAR  \
# 0     1330.587771    1246.109388
# 1      730.502396     314.094411
# 2      321.665141     370.525448
# 3     1696.196372    1528.110050
# 4   153464.479090  174107.259426
# 5    16300.379878   20380.136109
# 6    19985.167271   22491.160149
# 7       44.924199      56.041112
# 8       89.550115      65.969730
# 9      632.558423     651.007586
# 10     580.317155     664.985823
# 11      18.075837      16.232383
# 12     481.390297     935.295819
# 13    1450.564738    1660.977839
# 14    4668.346479    5827.190528
# 15    3455.493792    3563.738985
# 16    5996.794554    3708.808724
# 17     581.610483     459.150810
# 18     162.245587      71.728855
# 19     452.729963     426.777643
# 20      83.345221      77.387474
# 21  212526.924762  238622.688292
#
#                                   Section Description  Section_Num
# 0                       Live animals; animal products          1.0
# 1                                  Vegetable products          2.0
# 2   Animal or vegetable fats and oils and their cl...          3.0
# 3   Prepared foodstuffs; beverages, spirits and vi...          4.0
# 4                                    Mineral products          5.0
# 5       Products of the chemical or allied industries          6.0
# 6   Plastics and articles thereof; rubber and arti...          7.0
# 7   Raw hides and skins, leather, furskins and art...          8.0
# 8   Wood and articles of wood; wood charcoal; cork...          9.0
# 9   Pulp of wood or of other fibrous cellulosic ma...         10.0
# 10                      Textiles and textile articles         11.0
# 11  Footwear, headgear, umbrellas, sun umbrellas, ...         12.0
# 12  Articles of stone, plaster, cement, asbestos, ...         13.0
# 13  Natural or cultured pearls, precious or semi-p...         14.0
# 14             Base metals and articles of base metal         15.0
# 15  Machinery and mechanical appliances; electrica...         16.0
# 16  Vehicles, aircraft, vessels and associated tra...         17.0
# 17  Optical, photographic, cinematographic, measur...         18.0
# 18  Arms and ammunition; parts and accessories the...         19.0
# 19                Miscellaneous manufactured articles         20.0
# 20      Works of art, collectors' pieces and antiques         21.0
# 21                                              Total          NaN

# %% [markdown]
# ## Q4 sheet 1.1
# - Exports by Section

# %%
Q4_Ex_bysection= pd.read_csv('Cleaned_data/ITR Q42021A_1-2_clean.csv')
Q4_Ex_bysection.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q4_Ex_bysection
# Out:
#                                   Section Description   2021_Q3_mSAR  \
# 0                 الحيوانات الحية والمنتجات الحيوانية    1261.434116
# 1                                       منتجات نباتية     299.184048
# 2   شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...     340.523261
# 3   منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...    1742.577819
# 4                                   المنتجات المعدنية  207865.871133
# 5              منتجات الصناعات الكيماوية وما يتصل بها   21384.845760
# 6                    لدائن ومصنوعاتها؛ مطاط ومصنوعاته   24107.048874
# 7   صلال وجلود خام و جلود مدبوغة وجلود بفراء ومصنو...      52.724745
# 8   خشـب ومصنوعاتــه؛ فحم خشبـــي؛ فلين ومصنوعاته؛...      97.557234
# 9   عجائن من خشب أو من مواد ليفية سليلوزية أخر؛ ور...     600.362717
# 10                 مواد نسـجية ومصنوعات من هذه المواد     641.157285
# 11  أحذية، أغطية رأس، مظلات مطر، مظلات شمس، عصي مش...      26.326731
# 12  مصنوعات من حجر أو جص أو إسمنت أو حرير صخري (اس...     552.659798
# 13  لؤلؤ طبيعي أو مستنبت، أحجار كريمة أو شبه كريمة...     940.173355
# 14                             معادن عادية ومصنوعاتها    5559.126488
# 15  آلات وأجهزة آلية؛ معدات كهربائية؛ أجزاؤها؛ أجه...    3682.140723
# 16            عربات، طائرات، بواخر، ومعدات نقل مماثلة    5214.760101
# 17  أدوات وأجهزة للبصريات أو للتصوير الفوتوغرافي أ...     432.173900
# 18                     أسلحة وذخائر؛ أجزاؤها ولوازمها      55.136521
# 19                                سلع ومنتجات متـنوعة    1029.866433
# 20                 تحف فنية، قطع للمجموعات وقطع أثرية      76.196262
# 21                                           الإجمالي  275961.847304
#
#      2021_Q4_mSAR
# 0     1533.349188
# 1      531.968384
# 2      415.289859
# 3     1937.558877
# 4   241827.571306
# 5    25983.916057
# 6    24445.240573
# 7       59.655669
# 8      240.464454
# 9      876.253924
# 10     721.588806
# 11      20.587657
# 12     559.328708
# 13    1765.101166
# 14    6318.561156
# 15    4153.832749
# 16    8013.488632
# 17     496.040799
# 18      65.337838
# 19     426.542556
# 20      72.368307
# 21  320464.046665

# %% [markdown]
# ### Combining them:

# %%
Tot_21_Ex_Discription= Q2_Ex_bysection['Section Description']

# %%
tot_21_Exports= (Q2_Ex_bysection['2021_Q1_mSAR'] + Q2_Ex_bysection['2021_Q2_mSAR'] + Q4_Ex_bysection['2021_Q3_mSAR'] + Q4_Ex_bysection['2021_Q4_mSAR']).round(3)
totNum_21_Exports= pd.DataFrame(tot_21_Exports,  columns=['Tot_21_Exports'])
totNum_21_Exports
# Out:
#     Tot_21_Exports
# 0         5371.480
# 1         1875.749
# 2         1448.004
# 3         6904.443
# 4       777265.181
# 5        84049.278
# 6        91028.617
# 7          213.346
# 8          493.542
# 9         2760.183
# 10        2608.049
# 11          81.223
# 12        2528.675
# 13        5816.817
# 14       22373.225
# 15       14855.206
# 16       22933.852
# 17        1968.976
# 18         354.449
# 19        2335.917
# 20         309.297
# 21     1047575.507

# %%
totNum_21_Exports.rename(columns={'Tot_21_Exports': 'Value(millions SAR)'}, inplace=True)
Tot_21_Exports = pd.concat([totNum_21_Exports,Tot_21_Ex_Discription], axis=1)
Tot_21_Exports
# Out:
#     Value(millions SAR)                                Section Description
# 0              5371.480                      Live animals; animal products
# 1              1875.749                                 Vegetable products
# 2              1448.004  Animal or vegetable fats and oils and their cl...
# 3              6904.443  Prepared foodstuffs; beverages, spirits and vi...
# 4            777265.181                                   Mineral products
# 5             84049.278      Products of the chemical or allied industries
# 6             91028.617  Plastics and articles thereof; rubber and arti...
# 7               213.346  Raw hides and skins, leather, furskins and art...
# 8               493.542  Wood and articles of wood; wood charcoal; cork...
# 9              2760.183  Pulp of wood or of other fibrous cellulosic ma...
# 10             2608.049                      Textiles and textile articles
# 11               81.223  Footwear, headgear, umbrellas, sun umbrellas, ...
# 12             2528.675  Articles of stone, plaster, cement, asbestos, ...
# 13             5816.817  Natural or cultured pearls, precious or semi-p...
# 14            22373.225             Base metals and articles of base metal
# 15            14855.206  Machinery and mechanical appliances; electrica...
# 16            22933.852  Vehicles, aircraft, vessels and associated tra...
# 17             1968.976  Optical, photographic, cinematographic, measur...
# 18              354.449  Arms and ammunition; parts and accessories the...
# 19             2335.917                Miscellaneous manufactured articles
# 20              309.297      Works of art, collectors' pieces and antiques
# 21          1047575.507                                              Total

# %% [markdown]
# Now compare it with 2020 Exports by section & non-oil exports from 2011-2020

# %% [markdown]
# ## Q2 sheet 2.1
# - Imports by Section

# %%
Q2_Im_bysection= pd.read_csv('Cleaned_data/FT_2021_Q2_2-1_clean.csv')
Q2_Im_bysection.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q2_Im_bysection
# Out:
#      2021_Q1_mSAR   2021_Q2_mSAR  \
# 0     5124.105264    4644.582062
# 1     8425.518360    8412.106256
# 2     1052.075508    1014.701295
# 3     7074.709286    7146.520745
# 4     4123.354467    7310.717963
# 5    13903.884165   15887.925115
# 6     5050.023616    5604.432420
# 7      466.308885     408.905142
# 8     1174.583182    1410.686669
# 9     1452.554860    1747.468422
# 10    5505.859544    4910.724366
# 11    1103.814127     906.115958
# 12    2063.730818    1764.369658
# 13    5375.119551    5072.590651
# 14   11657.990332   12541.020653
# 15   27893.963758   26582.811135
# 16   22649.439999   24740.171216
# 17    4127.212287    3807.063015
# 18    6003.026390    1219.652885
# 19    3591.651804    3383.210658
# 20    1683.282102    2428.455551
# 21  139502.208305  140944.231835
#
#                                   Section Description  Section_Num
# 0                       Live animals; animal products          1.0
# 1                                  Vegetable products          2.0
# 2   Animal or vegetable fats and oils and their cl...          3.0
# 3   Prepared foodstuffs; beverages, spirits and vi...          4.0
# 4                                    Mineral products          5.0
# 5       Products of the chemical or allied industries          6.0
# 6   Plastics and articles thereof; rubber and arti...          7.0
# 7   Raw hides and skins, leather, furskins and art...          8.0
# 8   Wood and articles of wood; wood charcoal; cork...          9.0
# 9   Pulp of wood or of other fibrous cellulosic ma...         10.0
# 10                      Textiles and textile articles         11.0
# 11  Footwear, headgear, umbrellas, sun umbrellas, ...         12.0
# 12  Articles of stone, plaster, cement, asbestos, ...         13.0
# 13  Natural or cultured pearls, precious or semi-p...         14.0
# 14             Base metals and articles of base metal         15.0
# 15  Machinery and mechanical appliances; electrica...         16.0
# 16  Vehicles, aircraft, vessels and associated tra...         17.0
# 17  Optical, photographic, cinematographic, measur...         18.0
# 18  Arms and ammunition; parts and accessories the...         19.0
# 19                Miscellaneous manufactured articles         20.0
# 20      Works of art, collectors' pieces and antiques         21.0
# 21                                              Total          NaN

# %% [markdown]
# ## Q4 sheet 2.1
# - Imports by Section

# %%
Q4_Im_bysection= pd.read_csv('Cleaned_data/ITR Q42021A_2-1_clean.csv')
Q4_Im_bysection.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q4_Im_bysection
# Out:
#                                   Section Description   2021_Q3_mSAR  \
# 0                 الحيوانات الحية والمنتجات الحيوانية    4706.252804
# 1                                       منتجات نباتية    8340.891727
# 2   شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...    1096.588408
# 3   منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...    7006.645802
# 4                                   المنتجات المعدنية    8626.331296
# 5              منتجات الصناعات الكيماوية وما يتصل بها   15053.749638
# 6                    لدائن ومصنوعاتها؛ مطاط ومصنوعاته    5735.614725
# 7   صلال وجلود خام و جلود مدبوغة وجلود بفراء ومصنو...     445.318530
# 8   خشـب ومصنوعاتــه؛ فحم خشبـــي؛ فلين ومصنوعاته؛...    1559.317872
# 9   عجائن من خشب أو من مواد ليفية سليلوزية أخر؛ ور...    1834.251064
# 10                 مواد نسـجية ومصنوعات من هذه المواد    5265.496644
# 11  أحذية، أغطية رأس، مظلات مطر، مظلات شمس، عصي مش...    1044.552202
# 12  مصنوعات من حجر أو جص أو إسمنت أو حرير صخري (اس...    1744.404144
# 13  لؤلؤ طبيعي أو مستنبت، أحجار كريمة أو شبه كريمة...    4432.812363
# 14                             معادن عادية ومصنوعاتها   13875.196698
# 15  آلات وأجهزة آلية؛ معدات كهربائية؛ أجزاؤها؛ أجه...   27815.685118
# 16            عربات، طائرات، بواخر، ومعدات نقل مماثلة   25416.158582
# 17  أدوات وأجهزة للبصريات أو للتصوير الفوتوغرافي أ...    3713.413469
# 18                     أسلحة وذخائر؛ أجزاؤها ولوازمها    2817.120787
# 19                                سلع ومنتجات متـنوعة    3706.456827
# 20                 تحف فنية، قطع للمجموعات وقطع أثرية    2319.568116
# 21                                           الإجمالي  146555.826816
#
#      2021_Q4_mSAR
# 0     4526.153091
# 1     7558.866638
# 2     1099.633078
# 3     7373.740892
# 4     8623.421906
# 5    15532.935368
# 6     5355.059265
# 7      426.146853
# 8     1523.854678
# 9     1856.035267
# 10    5289.982170
# 11     875.018064
# 12    1857.123988
# 13    5548.635918
# 14   15319.101001
# 15   31557.284471
# 16   24157.388522
# 17    4028.803242
# 18    2349.069322
# 19    3792.007990
# 20    2488.478854
# 21  151138.740578

# %% [markdown]
# ### Combining them:

# %%
tot_21_Imports= (Q2_Im_bysection['2021_Q1_mSAR'] + Q2_Im_bysection['2021_Q2_mSAR'] + Q4_Im_bysection['2021_Q3_mSAR'] + Q4_Im_bysection['2021_Q4_mSAR']).round(3)
totNum_21_Imports= pd.DataFrame(tot_21_Imports,  columns=['Tot_21_Imports'])
totNum_21_Imports
# Out:
#     Tot_21_Imports
# 0        19001.093
# 1        32737.383
# 2         4262.998
# 3        28601.617
# 4        28683.826
# 5        60378.494
# 6        21745.130
# 7         1746.679
# 8         5668.442
# 9         6890.310
# 10       20972.063
# 11        3929.500
# 12        7429.629
# 13       20429.158
# 14       53393.309
# 15      113849.744
# 16       96963.158
# 17       15676.492
# 18       12388.869
# 19       14473.327
# 20        8919.785
# 21      578141.008

# %%
Tot_21_Im_Discription= Q2_Im_bysection['Section Description']
totNum_21_Imports.rename(columns={'Tot_21_Imports': 'Value(millions SAR)'}, inplace=True)
Tot_21_Imports = pd.concat([totNum_21_Imports,Tot_21_Im_Discription], axis=1)
Tot_21_Imports
# Out:
#     Value(millions SAR)                                Section Description
# 0             19001.093                      Live animals; animal products
# 1             32737.383                                 Vegetable products
# 2              4262.998  Animal or vegetable fats and oils and their cl...
# 3             28601.617  Prepared foodstuffs; beverages, spirits and vi...
# 4             28683.826                                   Mineral products
# 5             60378.494      Products of the chemical or allied industries
# 6             21745.130  Plastics and articles thereof; rubber and arti...
# 7              1746.679  Raw hides and skins, leather, furskins and art...
# 8              5668.442  Wood and articles of wood; wood charcoal; cork...
# 9              6890.310  Pulp of wood or of other fibrous cellulosic ma...
# 10            20972.063                      Textiles and textile articles
# 11             3929.500  Footwear, headgear, umbrellas, sun umbrellas, ...
# 12             7429.629  Articles of stone, plaster, cement, asbestos, ...
# 13            20429.158  Natural or cultured pearls, precious or semi-p...
# 14            53393.309             Base metals and articles of base metal
# 15           113849.744  Machinery and mechanical appliances; electrica...
# 16            96963.158  Vehicles, aircraft, vessels and associated tra...
# 17            15676.492  Optical, photographic, cinematographic, measur...
# 18            12388.869  Arms and ammunition; parts and accessories the...
# 19            14473.327                Miscellaneous manufactured articles
# 20             8919.785      Works of art, collectors' pieces and antiques
# 21           578141.008                                              Total

# %% [markdown]
# Total = 578141.008

# %% [markdown]
# ## Q2 sheet 2.3
# - Imports by Country

# %%
Q2_Im_bycountry= pd.read_csv('Cleaned_data/FT_2021_Q2_2-3_clean.csv')
Q2_Im_bycountry.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q2_Im_bycountry
# Out:
#       2021_Q1_mSAR   2021_Q2_mSAR               Country
# 0     28672.171130   25679.954387                 CHINA
# 1     12586.885145   13482.467715  UNITED ARAB EMIRATES
# 2     16078.199931   13099.942399                 U.S.A
# 3      6621.067160    7448.297571               GERMANY
# 4      7501.885938    7185.961510                 INDIA
# ..             ...            ...                   ...
# 146       0.191555       0.329661               CURACAO
# 147       0.039809       0.300528                 LIBYA
# 148       0.050014       0.230318     BRUNEI DARUSSALAM
# 149     107.592465       7.647941       OTHER COUNTRIES
# 150  139502.208305  140944.231835                 TOTAL
#
# [151 rows x 3 columns]

# %%
Q2_Im_bycountry['2021_Q1_mSAR'].unique()
# Out:
# array(['28672.171130000002', '12586.885145', '16078.199931',
#        '6621.0671600000005', '7501.885937999999', '6201.40603',
#        '4163.895711', '3033.796193', '4666.1114370000005', '945.049906',
#        '3604.0716469999998', '3120.0218290000003', '2086.304951',
#        '1743.324661', '1609.302683', '2193.93095', '2063.591865',
#        '1538.040274', '1925.5102769999999', '1191.188444', '1135.644221',
#        '1721.2078350000002', '1567.597855', '860.05902', '1275.374707',
#        '1090.0075510000001', '1460.59811', '1266.50122', '1054.394437',
#        '1347.9701850000001', '1098.247467', '364.347003', '573.296321',
#        '861.556732', '521.3209979999999', '787.11842', '427.243581',
#        '390.550488', '569.300714', '574.999051', '525.194654',
#        '429.73043199999995', '463.08090200000004', '518.36625',
#        '391.95986700000003', '277.742568', '448.389142',
#        '300.31039400000003', '635.479122', '263.253135',
#        '266.46583200000003', '178.19142599999998', '129.809313',
#        '243.005991', '235.205443', '323.80733299999997', '195.167206',
#        '84.61932599999999', '189.624256', '79.565438', '15.92654',
#        '107.21743000000001', '373.43756999999994', '72.991139',
#        '122.909232', '0.880456', '122.76349000000002', '0.004314',
#        '169.137568', '122.44078999999999', '43.013782', '80.177058',
#        '119.160992', '55.350525999999995', '104.30002200000001',
#        '50.284585', '69.454039', '45.024124', '46.294340000000005',
#        '20.201413000000002', '40.894686', '72.770112', '54.153256',
#        '17.497177999999998', '11.547509000000002', '18.852632',
#        '60.120062999999995', '15.336167', '39.489091', '16.622259',
#        '15.984469', '11.273261', '327.93647500000003',
#        '26.295766999999998', '13.409524000000001', '24.641219',
#        '17.513884', '25.783539', '3.3606909999999997', '15.858764',
#        '9.328356', '8.75142', '4.2737750000000005', '8.958886',
#        '9.445402', '3.6132910000000003', '1.45789', '6.227271',
#        '3.203608', '5.314348', '15.0705', '2.7312830000000003',
#        '0.415614', '4.829271', '4.124716', '25.261776', '2.744496',
#        '5.529604', '2.809333', '0.024637', '-', '0.157702', '1.031637',
#        '1.632245', '0.242', '1.001156', '1.999263', '0.715497',
#        '3.348565', '0.050282', '1.234185', '0.914303', '1.61765',
#        '0.513234', '0.5480970000000001', '1.3053059999999999',
#        '1.3707280000000002', '1.4695459999999998', '4.808070000000001',
#        '0.427983', '0.8813590000000001', '1.286542', '0.001399',
#        '0.599812', '0.69236', '0.191555', '0.039809', '0.050014',
#        '107.59246500000002', '139502.20830499998'], dtype=object)

# %%
Q2_Im_bycountry['2021_Q1_mSAR'] = Q2_Im_bycountry['2021_Q1_mSAR'].astype(float)

# %%
Q2_Im_bycountry.to_csv('Cleaned_data/FT_2021_Q2_2-3_clean.csv')

# %%
Q2_Im_bycountry
# Out:
#            2021_Q1_mSAR   2021_Q2_mSAR               Country
# 0    28672.171130000002   25679.954387                 CHINA
# 1          12586.885145   13482.467715  UNITED ARAB EMIRATES
# 2          16078.199931   13099.942399                 U.S.A
# 3    6621.0671600000005    7448.297571               GERMANY
# 4     7501.885937999999    7185.961510                 INDIA
# ..                  ...            ...                   ...
# 146            0.191555       0.329661               CURACAO
# 147            0.039809       0.300528                 LIBYA
# 148            0.050014       0.230318     BRUNEI DARUSSALAM
# 149  107.59246500000002       7.647941       OTHER COUNTRIES
# 150  139502.20830499998  140944.231835                 TOTAL
#
# [151 rows x 3 columns]

# %%
Q2_Im_bycountry.shape
# Out:
# (151, 3)

# %% [markdown]
# ## Q4 sheet 2.3
# - Imports by Country

# %%
Q4_Im_bycountry= pd.read_csv('Cleaned_data/ITR Q42021A_2-3_clean.csv')
Q4_Im_bycountry.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Q4_Im_bycountry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       148 non-null    object
#  1   2021_Q3_mSAR  148 non-null    float64
#  2   2021_Q4_mSAR  148 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.6+ KB

# %%
Q4_Im_bycountry
# Out:
#            Country   2021_Q3_mSAR   2021_Q4_mSAR
# 0            CHINA   31235.878496   31258.061824
# 1              USA   14920.396897   16103.400957
# 2              UAE   10385.818185   10805.359601
# 3            INDIA    8140.645779    7367.978312
# 4          GERMANY    6832.224905    6978.209918
# ..             ...            ...            ...
# 143      موريتانيا       0.015553       0.462222
# 144  جزيرة نورفولك       0.133750       0.378750
# 145        كوراساو       0.085575       0.370466
# 146     بقية الدول     102.835653       9.129419
# 147       الإجمالي  146555.826816  151138.740578
#
# [148 rows x 3 columns]

# %%
Q4_Im_bycountry['Country'].unique()
# Out:
# array(['CHINA', 'USA', 'UAE', 'INDIA', 'GERMANY', 'اليابان', 'مصر',
#        'ايطاليا', 'فرنسا', 'المملكة المتحدة', 'كوريا الجنوبية', 'سويسرا',
#        'البحرين', 'اندونيسيا', 'البرازيل', 'تايلاند', 'هولندا', 'اسبانيا',
#        'روسيا الاتحادية', 'سلطنة عمان', 'سنغافورة', 'بلجيكا', 'ماليزيا',
#        'تايوان', 'السويد', 'استراليا', 'هونج كونج', 'الأردن', 'فيتنام',
#        'ايرلندا', 'بولندا', 'أوكرانيا', 'اليونان', 'كندا', 'الدنمارك',
#        'المكسيك', 'جنوب افريقيا', 'النمسا', 'الأرجنتين', 'الكويت',
#        'رومانيا', 'التشيك', 'بنغلاديش', 'باكستان', 'قطر', 'فنلندا',
#        'نيوزيلندا', 'السودان', 'سوريا', 'المجر (هنغاريا)',
#        'جمهورية كونجو الديمقراطية', 'سلوفاكيا', 'بلغاريا', 'اثيوبيا',
#        'الجمهورية اليمنية', 'النرويج', 'الفلبين', 'البرتغال', 'المغرب',
#        'اكوادور', 'تشيلي', 'الاتحاد الأوربي، غير مذكورة في مكان آخر',
#        'مولدافيا', 'جواتيمالا', 'سريلانكا', 'كوستاريكا', 'صربيا', 'كينيا',
#        'لوكسمبورج', 'بورتوريكو', 'ميانمار (بورما)', 'ليتوانيا',
#        'كولومبيا', 'كامبوديا', 'كرواتيا', 'تونس', 'سلوفينيا', 'مالطا',
#        'جورجيا', 'فلسطين', 'العراق', 'افغانستان', 'البوسنة والهرسك',
#        'تركيا', 'بيرو', 'تنزانيا', 'قبرص', 'نيجيريا', 'ألبانيا',
#        'كازاخستان', 'زامبيا', 'أوزباكستان', 'لاتفيا', 'اسـتونيا',
#        'بيلاروس (روسيا البيضاء)', 'مقدونيا', 'لبنان',
#        'جمهورية الدومينيكان', 'أوروغواي', 'دومينيكا', 'باراغواي',
#        'أوغندا', 'السلفادور', 'مدغشقر', 'سان مارينو', 'ناميبيا',
#        'جمهورية الصومال', 'أيسلندا', 'ليختنشتاين', 'موريشيوس', 'غانا',
#        'هندوراس', 'بنما', 'جيبوتي', 'أروبا', 'جمهورية كوسوفو', 'زيمبابوي',
#        'اذربيجان', 'ساحل العاج (كوت ديفوار)', 'موزمبيق', 'الجزائر',
#        'توجو', 'مكاو', 'قرغيزستان (قرغيزيا)', 'بوليفيا', 'الكاميرون',
#        'الجابون', 'رواندا', 'إسواتيني (سوازيلاند)',
#        'جزر فيرجن البريطانية', 'السنغال', 'لاوس', 'نيكاراجوا', 'ليسوتو',
#        'غيانا', 'ملاوي', 'فنزويلا', 'ارمينيا', 'بروناي دار السلام',
#        'كونجو', 'سيراليون', 'موناكو', 'جزر فيجى', 'موريتانيا',
#        'جزيرة نورفولك', 'كوراساو', 'بقية الدول', 'الإجمالي'], dtype=object)

# %%
Q4_Im_bycountry[Q4_Im_bycountry['Country'].isin(['ليبيا'])]
# Out:
# Empty DataFrame
# Columns: [Country, 2021_Q3_mSAR, 2021_Q4_mSAR]
# Index: []

# %%
TotNum_21_Importsbycountry= (Q2_Im_bycountry['2021_Q1_mSAR'] + Q2_Im_bycountry['2021_Q2_mSAR'] + Q4_Im_bycountry['2021_Q3_mSAR'] + Q4_Im_bycountry['2021_Q4_mSAR'])
Tot_21_Importsbycountry= pd.DataFrame(TotNum_21_Importsbycountry, columns=['Value(millions SAR)'])
Tot_21_Importsbycountry
# Out:
#      Value(millions SAR)
# 0          116846.065837
# 1           57093.150714
# 2           50369.320116
# 3           29577.988822
# 4           28498.282271
# ..                   ...
# 146           112.486288
# 147        297694.907731
# 148                  NaN
# 149                  NaN
# 150                  NaN
#
# [151 rows x 1 columns]

# %%
# THIS IS WRONG
Country= Q2_Im_bycountry['Country']
Tot_21_Imcountries = pd.concat([Tot_21_Importsbycountry,Country], axis=1)
Tot_21_Imcountries
# Out:
#      Value(millions SAR)               Country
# 0          116846.065837                 CHINA
# 1           57093.150714  UNITED ARAB EMIRATES
# 2           50369.320116                 U.S.A
# 3           29577.988822               GERMANY
# 4           28498.282271                 INDIA
# ..                   ...                   ...
# 146           112.486288               CURACAO
# 147        297694.907731                 LIBYA
# 148                  NaN     BRUNEI DARUSSALAM
# 149                  NaN       OTHER COUNTRIES
# 150                  NaN                 TOTAL
#
# [151 rows x 2 columns]

# %%
Tot_21_Imcountries['Value(millions SAR)'] = Tot_21_Imcountries['Value(millions SAR)'].replace([50369.320116,
57093.150714, 29577.988822, 28498.282271],[60201.94029,47260.53065, 27879.79959, 30196.471542])
Tot_21_Imcountries
# Out:
#      Value(millions SAR)               Country
# 0          116846.065837                 CHINA
# 1           47260.530650  UNITED ARAB EMIRATES
# 2           60201.940290                 U.S.A
# 3           27879.799590               GERMANY
# 4           30196.471542                 INDIA
# ..                   ...                   ...
# 146           112.486288               CURACAO
# 147        297694.907731                 LIBYA
# 148                  NaN     BRUNEI DARUSSALAM
# 149                  NaN       OTHER COUNTRIES
# 150                  NaN                 TOTAL
#
# [151 rows x 2 columns]

# %%
Tot_21_Imcountries.loc[149,'Value(millions SAR)'] = 227.205478
Tot_21_Imcountries.loc[150,'Value(millions SAR)'] = 578141.008
Tot_21_Imcountries.loc[148,'Value(millions SAR)'] = 0.736373
Tot_21_Imcountries.drop(150, axis=0, inplace=True)

# %%
Tot_21_Imcountries.sort_values("Value(millions SAR)",ascending=False).head(10)
# Out:
#      Value(millions SAR)               Country
# 147        297694.907731                 LIBYA
# 0          116846.065837                 CHINA
# 2           60201.940290                 U.S.A
# 1           47260.530650  UNITED ARAB EMIRATES
# 4           30196.471542                 INDIA
# 3           27879.799590               GERMANY
# 5           22781.217435                 JAPAN
# 6           17674.917461                 ITALY
# 8           15772.009358                FRANCE
# 7           15095.790883                 EGYPT

# %%
Tot_21_Imcountries
# Out:
#      Value(millions SAR)               Country
# 0          116846.065837                 CHINA
# 1           47260.530650  UNITED ARAB EMIRATES
# 2           60201.940290                 U.S.A
# 3           27879.799590               GERMANY
# 4           30196.471542                 INDIA
# ..                   ...                   ...
# 145             1.502051          SIERRA LEONE
# 146           112.486288               CURACAO
# 147        297694.907731                 LIBYA
# 148             0.736373     BRUNEI DARUSSALAM
# 149           227.205478       OTHER COUNTRIES
#
# [150 rows x 2 columns]

# %%
USA = 14920.39699+ 16103.400957 + 16078.199931	+ 13099.9424 = 60201.94029
UAE = 10385.81819 + 10805.3596 + 12586.885145 + 13482.467715 = 47260.53065
INDIA = 8140.64578 + 7367.978312 + 7501.88594 + 7185.96151 = 30196.471542
GERMANY = 6832.22491 + 6978.20992 + 6621.06716 + 7448.2976 = 27879.79959
Other_Countries = 107.592465 + 7.647941 + 102.835653 + 9.129419 = 227.205478
Total = 139502.208305 + 140944.231835 + 146555.826816 + 151138.740578 = 578141.007534
