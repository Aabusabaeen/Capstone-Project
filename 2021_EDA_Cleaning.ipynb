# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import ggplot, aes, geom_density, geom_line, geom_point, ggtitle

# %% [markdown]
# #### Here, I would be combining 2021 quarters data to do a comparison with other years (2011-2020)

# %%
Q2_Ex_bysection = pd.read_excel('Data/FT 2021 Q2.xlsx', sheet_name='1.2')
Q2_Ex_bysection.to_csv('Cleaned_data/FT_2021_Q2_1-2.csv')

# %%
Q2_Im_bysection = pd.read_excel('Data/FT 2021 Q2.xlsx', sheet_name='2.1')
Q2_Im_bysection.to_csv('Cleaned_data/FT_2021_Q2_2-1.csv')

# %%
Q2_Im_bycountry = pd.read_excel('Data/FT 2021 Q2.xlsx', sheet_name='2.3')
Q2_Im_bycountry.to_csv('Cleaned_data/FT_2021_Q2_2-3.csv')

# %%
Q4_Ex_bysection = pd.read_excel('Data/ITR Q42021A.xlsx', sheet_name='1.1')
Q4_Ex_bysection.to_csv('Cleaned_data/ITR Q42021A_1-2.csv')

# %%
Q4_Im_bysection = pd.read_excel('Data/ITR Q42021A.xlsx', sheet_name='2.1')
Q4_Im_bysection.to_csv('Cleaned_data/ITR Q42021A_2-1.csv')

# %%
Q4_Im_bycountry = pd.read_excel('Data/ITR Q42021A.xlsx', sheet_name='2.3')
Q4_Im_bycountry.to_csv('Cleaned_data/ITR Q42021A_2-3.csv')

# %% [markdown]
# ## Q2 sheet 1.2, Exports by Section

# %%
Q2_Ex_bysection.head(10)
# Out:
#              Unnamed: 0                                         Unnamed: 1  \
# 0                   NaN                                                NaN
# 1  الصادرات حسب الاقسام                                                NaN
# 2    Exports by Section                                                NaN
# 3             رقم القسم                                          وصف القسم
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                     1                الحيوانات الحية والمنتجات الحيوانية
# 7                     2                                      منتجات نباتية
# 8                     3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 9                     4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
#
#                                Unnamed: 2        Unnamed: 3  \
# 0                                     NaN               NaN
# ...

# %%
Q2_Ex_bysection.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 7', 'الفهرس / Index'], axis=1, inplace=True)
Q2_Ex_bysection.drop([0,1,2,3,4,5], axis=0, inplace=True)
Q2_Ex_bysection.rename(columns={'Unnamed: 3': '2021_Q1_mSAR', 'Unnamed: 4': '2021_Q2_mSAR', 'Unnamed: 5': 'Section Description',
'Unnamed: 6': 'Section_Num'}, inplace=True)

# %%
Q2_Ex_bysection.to_csv('Cleaned_data/FT_2021_Q2_1-2_clean.csv')

# %% [markdown]
# ## Q2 sheet 2.1, Imports by Section

# %%
Q2_Im_bysection.head(10)
# Out:
#              Unnamed: 0                                         Unnamed: 1  \
# 0                   NaN                                                NaN
# 1  الواردات حسب الاقسام                                                NaN
# 2    Imports by Section                                                NaN
# 3             رقم القسم                                          وصف القسم
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                     1                الحيوانات الحية والمنتجات الحيوانية
# 7                     2                                      منتجات نباتية
# 8                     3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 9                     4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
#
#                                Unnamed: 2        Unnamed: 3  \
# 0                                     NaN               NaN
# ...

# %%
Q2_Im_bysection.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 7', 'الفهرس / Index'], axis=1, inplace=True)
Q2_Im_bysection.drop([0,1,2,3,4,5], axis=0, inplace=True)
Q2_Im_bysection.rename(columns={'Unnamed: 3': '2021_Q1_mSAR', 'Unnamed: 4': '2021_Q2_mSAR', 'Unnamed: 5': 'Section Description',
'Unnamed: 6': 'Section_Num'}, inplace=True)

# %%
# Out:
#      2021_Q1_mSAR   2021_Q2_mSAR  \
# 6     5124.105264    4644.582062
# 7      8425.51836    8412.106256
# 8     1052.075508    1014.701295
# 9     7074.709286    7146.520745
# 10    4123.354467    7310.717963
# 11   13903.884165   15887.925115
# 12    5050.023616     5604.43242
# 13     466.308885     408.905142
# 14    1174.583182    1410.686669
# 15     1452.55486    1747.468422
# 16    5505.859544    4910.724366
# 17    1103.814127     906.115958
# 18    2063.730818    1764.369658
# 19    5375.119551    5072.590651
# 20   11657.990332   12541.020653
# 21   27893.963758   26582.811135
# 22   22649.439999   24740.171216
# 23    4127.212287    3807.063015
# 24     6003.02639    1219.652885
# 25    3591.651804    3383.210658
# 26    1683.282102    2428.455551
# 27  139502.208305  140944.231835
#
#                                   Section Description Section_Num
# 6                       Live animals; animal products           1
# ...

# %%
Q2_Im_bysection.to_csv('Cleaned_data/FT_2021_Q2_2-1_clean.csv')

# %% [markdown]
# ## Q2 sheet 2.3, Imports by Country

# %%
Q2_Im_bycountry.head(10)
# Out:
#            Unnamed: 0                  Unnamed: 1  \
# 0                 NaN                         NaN
# 1  الواردات حسب الدول                         NaN
# 2  Imports by Country                         NaN
# 3               مرتبة                       الدول
# 4                 NaN                         NaN
# 5                 NaN                         NaN
# 6                   1                      الصـين
# 7                   2    الامارات العربية المتحدة
# 8                   3  الولايات المتحدة الامريكية
# 9                   4                     المانيا
#
#                                Unnamed: 2        Unnamed: 3  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                       الربع الثاني / Q2  الربع الأول / Q1
# 4                                    2020              2021
# ...

# %%
Q2_Im_bycountry.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 7', 'الفهرس / Index', 'Unnamed: 6'], axis=1, inplace=True)
Q2_Im_bycountry.drop([0,1,2,3,4,5], axis=0, inplace=True)
Q2_Im_bycountry.rename(columns={'Unnamed: 3': '2021_Q1_mSAR', 'Unnamed: 4': '2021_Q2_mSAR', 'Unnamed: 5': 'Country'}, inplace=True)

# %%
Q2_Im_bycountry
# Out:
#       2021_Q1_mSAR   2021_Q2_mSAR               Country
# 6      28672.17113   25679.954387                 CHINA
# 7     12586.885145   13482.467715  UNITED ARAB EMIRATES
# 8     16078.199931   13099.942399                 U.S.A
# 9       6621.06716    7448.297571               GERMANY
# 10     7501.885938     7185.96151                 INDIA
# ..             ...            ...                   ...
# 152       0.191555       0.329661               CURACAO
# 153       0.039809       0.300528                 LIBYA
# 154       0.050014       0.230318     BRUNEI DARUSSALAM
# 155     107.592465       7.647941       OTHER COUNTRIES
# 156  139502.208305  140944.231835                 TOTAL
#
# [151 rows x 3 columns]

# %%
Q2_Im_bycountry[Q2_Im_bycountry['2021_Q1_mSAR'].isin(['-'])]
# Out:
#     2021_Q1_mSAR 2021_Q2_mSAR             Country
# 126            -     2.303105  REPUBLIC OF KOSOVO
# 140            -     0.871246            SURINAME

# %%
Q2_Im_bycountry['2021_Q1_mSAR'].replace({'-': '1.5'}, inplace=True)
# Out:
# 6        28672.17113
# 7       12586.885145
# 8       16078.199931
# 9         6621.06716
# 10       7501.885938
#            ...
# 152         0.191555
# 153         0.039809
# 154         0.050014
# 155       107.592465
# 156    139502.208305
# Name: 2021_Q1_mSAR, Length: 151, dtype: object

# %%
Q2_Im_bycountry.to_csv('Cleaned_data/FT_2021_Q2_2-3_clean.csv')

# %% [markdown]
# ## Q4 sheet 1.1, Exports by Section

# %%
Q4_Ex_bysection.head(10)
# Out:
#              Unnamed: 0                                         Unnamed: 1  \
# 0                   NaN                                                NaN
# 1  الصادرات حسب الاقسام                                                NaN
# 2             رقم القسم                                          وصف القسم
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                     1                الحيوانات الحية والمنتجات الحيوانية
# 6                     2                                      منتجات نباتية
# 7                     3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 8                     4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
# 9                     5                                  المنتجات المعدنية
#
#             Unnamed: 2     Unnamed: 3     Unnamed: 4  Unnamed: 5  الفهرس
# ...

# %%
Q4_Ex_bysection.drop(['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 5', 'الفهرس'], axis=1, inplace=True)
Q4_Ex_bysection.drop([0,1,2,3,4], axis=0, inplace=True)
Q4_Ex_bysection.rename(columns={'Unnamed: 1': 'Section Description', 'Unnamed: 3': '2021_Q3_mSAR', 'Unnamed: 4': '2021_Q4_mSAR' }, inplace=True)

# %%
Q4_Ex_bysection.to_csv('Cleaned_data/ITR Q42021A_1-2_clean.csv')

# %% [markdown]
# ## Q4 sheet 2.1, Imports by Section

# %%
Q4_Im_bysection.head(10)
# Out:
#              Unnamed: 0                                         Unnamed: 1  \
# 0                   NaN                                                NaN
# 1  الواردات حسب الاقسام                                                NaN
# 2             رقم القسم                                          وصف القسم
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                     1                الحيوانات الحية والمنتجات الحيوانية
# 6                     2                                      منتجات نباتية
# 7                     3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 8                     4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
# 9                     5                                  المنتجات المعدنية
#
#             Unnamed: 2    Unnamed: 3    Unnamed: 4  Unnamed: 5  الفهرس
# 0                  NaN           NaN           NaN         NaN     NaN
# ...

# %%
Q4_Im_bysection.drop(['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 5', 'الفهرس'], axis=1, inplace=True)
Q4_Im_bysection.drop([0,1,2,3,4], axis=0, inplace=True)
Q4_Im_bysection.rename(columns={'Unnamed: 1': 'Section Description', 'Unnamed: 3': '2021_Q3_mSAR', 'Unnamed: 4': '2021_Q4_mSAR'}, inplace=True)

# %%
Q4_Im_bysection
# Out:
#                                   Section Description   2021_Q3_mSAR  \
# 5                 الحيوانات الحية والمنتجات الحيوانية    4706.252804
# 6                                       منتجات نباتية    8340.891727
# 7   شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...    1096.588408
# 8   منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...    7006.645802
# 9                                   المنتجات المعدنية    8626.331296
# 10             منتجات الصناعات الكيماوية وما يتصل بها   15053.749638
# 11                   لدائن ومصنوعاتها؛ مطاط ومصنوعاته    5735.614725
# 12  صلال وجلود خام و جلود مدبوغة وجلود بفراء ومصنو...      445.31853
# 13  خشـب ومصنوعاتــه؛ فحم خشبـــي؛ فلين ومصنوعاته؛...    1559.317872
# 14  عجائن من خشب أو من مواد ليفية سليلوزية أخر؛ ور...    1834.251064
# 15                 مواد نسـجية ومصنوعات من هذه المواد    5265.496644
# 16  أحذية، أغطية رأس، مظلات مطر، مظلات شمس، عصي مش...    1044.552202
# 17  مصنوعات من حجر أو جص أو إسمنت أو حرير صخري (اس...    1744.404144
# ...

# %%
Q4_Im_bysection.to_csv('Cleaned_data/ITR Q42021A_2-1_clean.csv')

# %% [markdown]
# ## Q4 sheet 2.3, Imports by Country

# %%
Q4_Im_bycountry.head(10)
# Out:
#            Unnamed: 0                  Unnamed: 1           Unnamed: 2  \
# 0                 NaN                         NaN                  NaN
# 1  الواردات حسب الدول                         NaN                  NaN
# 2               مرتبة                       الدول         الربع الرابع
# 3                 NaN                         NaN                 2020
# 4                 NaN                         NaN  القيمة (مليون ريال)
# 5                   1                       الصين         27663.397783
# 6                   2  الولايات المتحدة الأمريكية         14149.757937
# 7                   3    الامارات العربية المتحدة           9758.62298
# 8                   4                       الهند          6691.131033
# 9                   5                     المانيا          6473.256585
#
#      Unnamed: 3    Unnamed: 4  Unnamed: 5  الفهرس
# 0           NaN           NaN         NaN     NaN
# 1           NaN           NaN         NaN     NaN
# ...

# %%
Q4_Im_bycountry.drop(['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 5', 'الفهرس'], axis=1, inplace=True)
Q4_Im_bycountry.drop([0,1,2,3,4], axis=0, inplace=True)

# %%
Q4_Im_bycountry.rename(columns={'Unnamed: 1': 'Country', 'Unnamed: 3': '2021_Q3_mSAR', 'Unnamed: 4': '2021_Q4_mSAR'}, inplace=True)
Q4_Im_bycountry.replace({'الصين': 'CHINA', 'الولايات المتحدة الأمريكية': 'USA','الامارات العربية المتحدة': 'UAE',
'الهند': 'INDIA', 'المانيا': 'GERMANY'}, inplace=True)

# %%
Q4_Im_bycountry
# Out:
#            Country   2021_Q3_mSAR   2021_Q4_mSAR
# 5            CHINA   31235.878496   31258.061824
# 6              USA   14920.396897   16103.400957
# 7              UAE   10385.818185   10805.359601
# 8            INDIA    8140.645779    7367.978312
# 9          GERMANY    6832.224905    6978.209918
# ..             ...            ...            ...
# 148      موريتانيا       0.015553       0.462222
# 149  جزيرة نورفولك       0.133750       0.378750
# 150        كوراساو       0.085575       0.370466
# 151     بقية الدول     102.835653       9.129419
# 152       الإجمالي  146555.826816  151138.740578
#
# [148 rows x 3 columns]

# %%
Q4_Im_bycountry.to_csv('Cleaned_data/ITR Q42021A_2-3_clean.csv')

# %% [markdown]
# ### - Use the concad method here, but first, make sure you call the columns to be combined
# ### - Or you can do: overall = Q2imports['2021_Q2_mSAR'] + q4imports['2021_q3_mSAR'] ((much easier))

# %%
tot_21_Im
# Out:
# 6      9768.687326
# 7     16837.624616
# 8      2066.776803
# 9     14221.230031
# 10     11434.07243
# 11     29791.80928
# 12    10654.456036
# 13      875.214027
# 14     2585.269851
# 15     3200.023282
# 16     10416.58391
# 17     2009.930085
# 18     3828.100476
# 19    10447.710202
# 20    24199.010985
# 21    54476.774893
# 22    47389.611215
# 23     7934.275302
# 24     7222.679275
# 25     6974.862462
# 26     4111.737653
# 27    280446.44014
# dtype: object

# %%
Im_bysection2021 = pd.concat()
