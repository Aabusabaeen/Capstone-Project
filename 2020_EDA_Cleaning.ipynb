# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data was found in: https://www.stats.gov.sa/ar/325

# %% [markdown]
# # Trading2020
#  - This file does not seem to seperate oil vs non-oil exports as in sheet 1-1 compared to sheet 1.1 in Trading20
# ## Sheet 1-1
# - Over all Exports & Imports weight & value from 2011 - 2020

# %%
Trading_data = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='1-1')
Trading_data.to_csv("Cleaned_data/Trading2020_1-1.csv", sep=",")

# %%
Trading_data.drop([0,1,2,3,4,5], axis=0, inplace=True)
Trading_data.drop('R', axis=1, inplace=True)

# %%
Trading_data.rename(columns={'Unnamed: 0': 'Year', 'Unnamed: 1': 'Imports Weight(1000 Tons)',
 'Unnamed: 2' : 'Imports Vaule(Millions SAR)', 'Unnamed: 3' : 'Exports Weight(1000 Tons)', 'Unnamed: 4' : 'Exports Vaule(Millions SAR)'}, inplace= True)

# %%
Cleaned_Trading20 = Trading_data.copy(deep= True)

# %%
# same as above
Cleaned_Trading20 = pd.DataFrame(Trading_data)

# %%
Cleaned_Trading20
# Out:
#     Year Imports Weight(1000 Tons) Imports Vaule(Millions SAR)  \
# 6   2011                     63161                      493449
# 7   2012                     74493                      583473
# 8   2013                     82881                      630582
# 9   2014                     82536                      651876
# 10  2015                     84206                      655033
# 11  2016                     76731                      525636
# 12  2017                     75998                      504447
# 13  2018                     75239                      513993
# 14  2019                     77512                      574361
# 15  2020                     86137                      517491
#
#    Exports Weight(1000 Tons) Exports Vaule(Millions SAR)
# 6                     449823                     1367620
# 7                     467012                     1456502
# 8                     462339                     1409523
# ...

# %%
Cleaned_Trading20['Difference in Weights']= Cleaned_Trading20['Exports Weight(1000 Tons)'] - Cleaned_Trading20['Imports Weight(1000 Tons)']
Cleaned_Trading20
# Out:
#     Year Imports Weight(1000 Tons) Imports Vaule(Millions SAR)  \
# 6   2011                     63161                      493449
# 7   2012                     74493                      583473
# 8   2013                     82881                      630582
# 9   2014                     82536                      651876
# 10  2015                     84206                      655033
# 11  2016                     76731                      525636
# 12  2017                     75998                      504447
# 13  2018                     75239                      513993
# 14  2019                     77512                      574361
# 15  2020                     86137                      517491
#
#    Exports Weight(1000 Tons) Exports Vaule(Millions SAR) Difference in Weights
# 6                     449823                     1367620                386662
# 7                     467012                     1456502                392519
# ...

# %%
Cleaned_Trading20['Difference in Value']= Cleaned_Trading20['Exports Vaule(Millions SAR)'] - Cleaned_Trading20['Imports Vaule(Millions SAR)']
Cleaned_Trading20
# Out:
#     Year Imports Weight(1000 Tons) Imports Vaule(Millions SAR)  \
# 6   2011                     63161                      493449
# 7   2012                     74493                      583473
# 8   2013                     82881                      630582
# 9   2014                     82536                      651876
# 10  2015                     84206                      655033
# 11  2016                     76731                      525636
# 12  2017                     75998                      504447
# 13  2018                     75239                      513993
# 14  2019                     77512                      574361
# 15  2020                     86137                      517491
#
#    Exports Weight(1000 Tons) Exports Vaule(Millions SAR)  \
# 6                     449823                     1367620
# 7                     467012                     1456502
# 8                     462339                     1409523
# ...

# %%
plt.scatter(Cleaned_Trading20['Year'], Cleaned_Trading20['Imports Weight(1000 Tons)'])
plt.scatter(Cleaned_Trading20['Year'], Cleaned_Trading20['Exports Weight(1000 Tons)'])
plt.plot(Cleaned_Trading20[['Year']], Cleaned_Trading20[['Imports Weight(1000 Tons)']], c='red', label='Imports Weight(1000 Tons)')
plt.plot(Cleaned_Trading20[['Year']], Cleaned_Trading20[['Exports Weight(1000 Tons)']], c='blue', label='Exports Weight(1000 Tons)')
plt.legend()
plt.title('Imports Weight(1000 Tons) from 2011-2020')
plt.show()

# %% [markdown]
# ### Difference in Weights of Tradings over the years

# %%
plt.bar(Cleaned_Trading20['Year'], Cleaned_Trading20['Difference in Weights'])
plt.title('Difference in Trading Weights over the years')
# Out:
# Text(0.5, 1.0, 'Difference in Trading Weights over the years')

# %%
plt.scatter(Cleaned_Trading20['Year'], Cleaned_Trading20['Difference in Weights'])
plt.title('Difference in Trading Weights over the years')
# Out:
# Text(0.5, 1.0, 'Difference in Trading Weights over the years')

# %% [markdown]
# ### Difference in value of Tradings over the years

# %%
plt.bar(Cleaned_Trading20['Year'], Cleaned_Trading20['Difference in Value'])
plt.title('Difference in Trading Values over the years')
# Out:
# Text(0.5, 1.0, 'Difference in Trading Values over the years')

# %%
plt.scatter(Cleaned_Trading20['Year'], Cleaned_Trading20['Difference in Value'])

# %%
Cleaned_Trading20.to_csv('Cleaned_data/Trading2020_1-1_clean.csv')

# %% [markdown]
# ## Sheet 1-3
# - Kind of materials & if imported/exported
# - 2018 - 2020

# %%
TD_materials0 = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='1-3')
TD_materials0.to_csv("Cleaned_data/Trading2020_1-3.csv", sep=",")

# %%
TD_materials = pd.DataFrame(TD_materials0)

# %%
TD_materials
# Out:
#    Unnamed: 0                Unnamed: 1           Unnamed: 2 Unnamed: 3  \
# 0         NaN  التجارة حسب طبيعة المواد                  NaN        NaN
# 1         NaN  Trade by Nature of Items                  NaN        NaN
# 2         NaN                       NaN                  NaN        NaN
# 3         NaN            الوزن (الف طن)  القيمة (مليون ريال)        NaN
# 4     التجارة                    المواد                 2018        NaN
# 5     التجارة                       NaN                الوزن     القيمة
# 6         NaN                       NaN               Weight      Value
# 7      واردات                       خام                26661      26376
# 8      واردات                 نصف مصنعة                25868     123648
# 9      واردات                     مصنعة                22711     363968
# 10   الصادرات                       خام               371803     722108
# 11   الصادرات                 نصف مصنعة                63030     183069
# ...

# %%
TD_materials.drop(['Unnamed: 0', 'R', 'Unnamed: 1'], axis=1, inplace=True)
TD_materials.drop([0,1,2,3,4,5,6], axis=0, inplace=True)

# %%
TD_materials.rename(columns={'Unnamed: 2' : '2018 Weight(1000 Tons)', 'Unnamed: 3' : '2018 Value(Millions SAR)', 
'Unnamed: 4' : '2019 Weight(1000 Tons)', 'Unnamed: 5' : '2019 Value(Millions SAR)', 'Unnamed: 6' : '2020 Weight(1000 Tons)',
 'Unnamed: 7' : '2020 Value(Millions SAR)', 'Unnamed: 8' : 'Kind of material', 'Unnamed: 9' : 'Import/Export'}, inplace=True)

# %%
TD_materials.to_csv('Cleaned_data/Trading2020_1-3_clean.csv')

# %%
TD_materials
# Out:
#    2018 Weight(1000 Tons) 2018 Value(Millions SAR) 2019 Weight(1000 Tons)  \
# 7                   26661                    26376                  15299
# 8                   25868                   123648                  35094
# 9                   22711                   363968                  27119
# 10                 371803                   722108                 357130
# 11                  63030                   183069                  67896
# 12                  74965                   198724                  67236
#
#    2019 Value(Millions SAR) 2020 Weight(1000 Tons) 2020 Value(Millions SAR)  \
# 7                     19603                  19426                    22211
# 8                    127428                  36109                   124171
# 9                    427330                  30603                   371109
# 10                   639256                 342440                   387861
# ...

# %% [markdown]
# ### Split the imports from exports?

# %% [markdown]
# ## Sheet 1-5
# - Imports by Transoprtation Type
# - Values & Weights
# - 2018 - 2020

# %%
Imports_byTransoprtType0 = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='1-5')
Imports_byTransoprtType0.to_csv("Cleaned_data/Trading2020_1-5.csv", sep=",")

# %%
Imports_byTransoprtType= pd.DataFrame(Imports_byTransoprtType0)

# %%
Imports_byTransoprtType
# Out:
#                Unnamed: 0           الواردات حسب وسيلة النقل     Unnamed: 2  \
# 0                     NaN  Imports by Type of Transportation            NaN
# 1          الوزن (الف طن)                القيمة (مليون ريال)            NaN
# 2                  المواد                               2019            NaN
# 3                     NaN                              الوزن         القيمة
# 4                     NaN                             Weight          Value
# 5  الواردات عن طريق البحر                       66260.247914  310406.535978
# 6   الواردات عن طريق البر                        8343.995809   76875.211899
# 7   الواردات عن طريق الجو                         634.929403  126710.942322
# 8                 المجموع                       75239.173126  513992.690199
#
#      Unnamed: 3     Unnamed: 4         Unnamed: 5     Unnamed: 6  \
# 0           NaN            NaN                NaN            NaN
# 1           NaN            NaN  Weight(1000 Tons)            NaN
# ...

# %%
Imports_byTransoprtType.rename(columns={'الواردات حسب وسيلة النقل' :  'Weight (1000 Tons) 2018',
'Unnamed: 2' : '2018 Value (millions in SAR)', 'Unnamed: 3' : '2019 Weight (1000 Tons)', 'Unnamed: 4' : '2019 Value (millions in SAR)', 
'Unnamed: 5' : '2020 Weight (1000 Tons)', 'Unnamed: 6' : '2020 Value (millions in SAR)', 'Unnamed: 7' : 'Importing Type'}, inplace=True)

# %%
Imports_byTransoprtType.drop([0,1,2,3,4,8], axis=0, inplace=True)
Imports_byTransoprtType.drop(['Unnamed: 0', 'R'], axis=1, inplace=True)

# %%
Imports_byTransoprtType
# Out:
#   Weight (1000 Tons) 2018 2018 Value (millions in SAR)  \
# 5            66260.247914                310406.535978
# 6             8343.995809                 76875.211899
# 7              634.929403                126710.942322
#
#   2019 Weight (1000 Tons) 2019 Value (millions in SAR)  \
# 5            66366.941453                352081.497419
# 6             10386.98389                 83588.749138
# 7              757.717624                138691.208044
#
#   2020 Weight (1000 Tons) 2020 Value (millions in SAR)   Importing Type
# 5            75821.060302                320312.112449   Imports By Sea
# 6             9619.117143                 75991.218771  Imports By Land
# 7              697.093139                121187.257807   Imports By Air

# %%
Imports_byTransoprtType.to_csv('Cleaned_data/Trading2020_1-5_clean.csv')

# %%
Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].sum()
# Out:
# Weight (1000 Tons) 2018    75239.173126
# 2019 Weight (1000 Tons)    77511.642967
# 2020 Weight (1000 Tons)    86137.270584
# dtype: object

# %% [markdown]
# Source to navigate the first cell value in the columns:
# https://www.stackvidhya.com/get-value-of-cell-from-a-pandas-dataframe/

# %%
plt.style.use('seaborn-darkgrid') # to have a background that makes the chart more visible
x = Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].values[0]
labels1= ['2018', '2019', '2020']
plt.figure(figsize = [8, 8])
plt.pie(x, labels = labels1, counterclock= False, autopct= lambda p:f'{p:.2f}%')
plt.title('Imports by Sea from 2018-2020', fontsize= 17)
plt.legend(Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].values[0], 
loc='upper left', fontsize= 10)
plt.show()

# %%
x = ['2018', '2019', '2020']
sea = Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].values[0]
land = Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].values[1]
air = Imports_byTransoprtType[["Weight (1000 Tons) 2018", "2019 Weight (1000 Tons)", "2020 Weight (1000 Tons)"]].values[2]
sea_land = list(np.add(sea,land))
plt.figure(figsize = [7,6])
plt.bar(x, sea, 0.5, label= 'Sea')
plt.bar(x, land, 0.4, bottom= sea, label= 'Land')
plt.bar(x,air, 0.3, bottom= sea_land, label= 'Air')
plt.title('Weight of Imports by Transportation Types', fontsize= 17)
plt.xlabel('Year',fontsize= 15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.ylabel('Weights in 1000 Tons', fontsize= 15)
plt.legend(loc= 'upper left', fontsize= 12)
plt.show()

# %% [markdown]
# ## Sheet 2-1
#
# - Top 50 Import Commodities by value with 3 Major Trading Countries
# - Values & Weights
# - 2020 only

# %%
Imports_Top50_fromTop30 = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='2-1')
Imports_Top50_fromTop30.to_csv("Cleaned_data/Trading2020_2-1.csv", sep=",")

# %%
Imports_Top50_fromTop3= pd.DataFrame(Imports_Top50_fromTop30)

# %%
Imports_Top50_fromTop3
# Out:
#       Unnamed: 0  أعلى 50 صنف مستورد بالنسبة للقيمة مع 3 دول رئيسة مصدرة  \
# 0            NaN  Top 50 Import Commodities by value with 3 Majo...
# 1    الوزن بالطن                                                NaN
# 2     رمز السلعة                                         وصف السلعة
# 3            NaN                                                NaN
# 4       85171200  أجهزة هاتف للشبكات الخليوية أو غيرها من الشبكا...
# ..           ...                                                ...
# 149          NaN                                                NaN
# 150          NaN                                                NaN
# 151     23040000         كسب وغيره من بقايا صلبة، من زيت فول الصويا
# 152          NaN                                                NaN
# 153          NaN                                                NaN
#
#             Unnamed: 2   Unnamed: 3          Unnamed: 4       Unnamed: 5  \
# ...

# %%
Imports_Top50_fromTop3.drop(['Unnamed: 0', ' أعلى 50 صنف مستورد بالنسبة للقيمة مع 3 دول رئيسة مصدرة', 'Unnamed: 2', 'Unnamed: 3', 
'Unnamed: 6', 'R'], axis=1, inplace=True)
Imports_Top50_fromTop3.drop([0,1,2,3], axis=0, inplace=True)
Imports_Top50_fromTop3.rename(columns={'Unnamed: 4' : 'Percent To Total', 'Unnamed: 5': 'Accum. Percent', 'Unnamed: 7': 'Country',
'Unnamed: 8' : 'Value(millions SAR)', 'Unnamed: 9' : 'Weight(Tons)', 'Unnamed: 10': 'Commodity Name', 
'Unnamed: 11': 'Commodity Code'}, inplace=True)

# %%
Imports_Top50_fromTop3
# Out:
#     Percent To Total Accum. Percent         Country Value(millions SAR)  \
# 4                NaN            NaN           CHINA        12589.189336
# 5                NaN            NaN         VIETNAM         1857.808496
# 6                NaN            NaN           INDIA          608.146995
# 7                NaN            NaN           CHINA         2758.417565
# 8                NaN            NaN           U.S.A         2386.783067
# ..               ...            ...             ...                 ...
# 149              NaN            NaN  UNITED KINGDOM          267.046152
# 150              NaN            NaN           CHINA          159.145744
# 151              NaN            NaN       ARGENTINA         1271.459024
# 152              NaN            NaN          BRAZIL           69.269627
# 153              NaN            NaN           U.S.A           55.245184
#
#     Weight(Tons)                                     Commodity Name  \
# ...

# %%
Imports_Top50_fromTop3.isnull().sum()
# Out:
# Percent To Total       150
# Accum. Percent         150
# Country                  0
# Value(millions SAR)      0
# Weight(Tons)             0
# Commodity Name           2
# Commodity Code           2
# dtype: int64

# %%
Imports_Top50_fromTop3['Commodity Name'].unique()
# Out:
# array([' Telephones for cellular networks or for other wireless networks',
#        'PRIVATE CARS, CURRENT, SPARK-IGNITION, NOT OVER 1000 CC',
#        'OTHER MEDICINE, RETAIL',
#        'PRIVATE CARS, CURRENT, SPARK IGNITION, 1001 TO 1500 CC',
#        'OTHER FUEL OILS',
#        'the personal effects and used household items brought into the co',
#        'OTHER PARTS OF AEROPLANES OR HELICOPTERS', 'BARLEY',
#        'SIMI-MILLED OR WHOLLY MILLED RICE WHETHER OR NOTPOLISHED OR GLAZE',
#        'Other Machines for the reception, conversion and transmission',
#        'GOLD INGOTS',
#        'FERROUS PRODUCTS FROM THE DIRECT REDUCTION OF IRON ORE',
#        'JEEPS, CURRENT, SPARK IGNITION, 1001 TO 1500 CC',
#        'Air-Conditioning Equipment (Freon)',
#        'Portable Auto Data Processing Machine with C.P.U',
#        'ENGINE  GASOLINE', 'GOLDEN CORN',
#        'PRIVATE CARS, 1-YEAR, SPARK-IGNITION, NOT OVER 1000 CC',
#        'REFINED COPPER WIRE OVER 6 MM THICK',
# ...

# %%
Imports_Top50_fromTop3['Country'].unique()
# Out:
# array(['CHINA', 'VIETNAM', 'INDIA', 'U.S.A', 'SOUTH KOREA', 'GERMANY',
#        'FRANCE', 'JAPAN', 'THAILAND', 'EGYPT', 'SINGAPORE', 'NETHERLANDS',
#        'UNITED ARAB EMIRATES', 'HONG KONG', 'UNITED KINGDOM',
#        'RUSSIAN FEDERATION', 'UKRAINE', 'PAKISTAN', 'FINLAND',
#        'SOUTH AFRICA', 'SWITZERLAND', 'SULTANATE OF OMAN', 'SWEDEN',
#        'BAHRAIN', 'INDONESIA', 'ARGENTINA', 'BRAZIL',
#        'CONGO, THE DEMOCRATIC REPUBLIC', 'ZAMBIA', 'SPAIN', 'TURKEY',
#        'POLAND', 'LITHUANIA', 'MALAYSIA', 'IRELAND', 'JORDAN',
#        'CZECH REPUBLIC', 'PANAMA', 'ITALY'], dtype=object)

# %% [markdown]
# Find away to fix percent & accum. percent

# %% [markdown]
# ## Sheet 3-4
# Imports by Commodities and Countries. Values & Weights

# %%
Imports_commodityCountry0 = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='3-4')
Imports_commodityCountry0.to_csv("Cleaned_data/Trading2020_3-4.csv", sep=",")

# %%
Imports_commodityCountry = pd.DataFrame(Imports_commodityCountry0)

# %%
Imports_commodityCountry.head(10)
# Out:
#    Unnamed: 0                            Unnamed: 1 Unnamed: 2  \
# 0         NaN                                   NaN        NaN
# 1         NaN                              الوزن طن        NaN
# 2  رمز السلعة                                 الوصف     الدولة
# 3         NaN                                   NaN        NaN
# 4     1022900                        غيرها من أبقار        120
# 5     1022900                        غيرها من أبقار        439
# 6     1022900                        غيرها من أبقار        526
# 7     1022900                        غيرها من أبقار        540
# 8     1022900                        غيرها من أبقار        544
# 9     1041010  حيوانات من فصيله الضان اصيله للانسال        112
#
#                  Unnamed: 3           الواردات حسب الأصناف والدول Unnamed: 5  \
# 0                       NaN  Imports by Commodities and Countries        NaN
# 1        القيمة بالالف ريال                                   عام       2020
# ...

# %%
Imports_commodityCountry.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis= 1, inplace=True)
Imports_commodityCountry.drop([0,1,2,3], axis=0, inplace=True)
Imports_commodityCountry.rename(columns={'الواردات حسب الأصناف والدول': 'Quantity/Units' ,'Unnamed: 5': 'Weights (Tons)', 
'Unnamed: 6': 'Value(1000 SAR)','Unnamed: 7': 'Country Name', 'Unnamed: 8': 'Country Code' , 'R' : 'Commodity Code',
 'Unnamed: 9' : 'Description'}, inplace=True)

# %%
Imports_commodityCountry
# Out:
#       Quantity/Units Weights (Tons) Value(1000 SAR)          Country Name  \
# 4               3292            368            3004  UNITED ARAB EMIRATES
# 5              48652          19013          144297                BRAZIL
# 6               9228           4186           44258                 SPAIN
# 7              17860           7035           75210               ROMANIA
# 8               5069           2031           19504               UKRAINE
# ...              ...            ...             ...                   ...
# 24648              0            956           10700                 U.S.A
# 24649              0             86            9341               GERMANY
# 24650              0             36            2483                FRANCE
# 24651              0            525            6072       Other Countries
# 24652              0        1869997        28674503   Different Countries
#
#       Country Code                       Description Commodity Code
# ...

# %%
Imports_commodityCountry.isnull().sum()
# Out:
# Quantity/Units      0
# Weights (Tons)      0
# Value(1000 SAR)     0
# Country Name        0
# Country Code        0
# Description        25
# Commodity Code      0
# dtype: int64

# %% [markdown]
# ## Sheet 3-7
# Exports by Country Groups and Major Commodities. Values & weights

# %%
Exports_commodityGroup0 = pd.read_excel ('Data/Trading2020.xlsx', sheet_name='3-7')
Exports_commodityGroup0.to_csv("Cleaned_data/Trading2020_3-7.csv", sep=",")

# %%
Exports_commodityGroup =pd.DataFrame(Exports_commodityGroup0)

# %%
Exports_commodityGroup.head(10)
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1                  الوزن طن
# 2                       NaN
# 3                       NaN
# 4              مجموعة الدول
# 5                       NaN
# 6  دول مجلس التعاون الخليجي
# 7  دول مجلس التعاون الخليجي
# 8  دول مجلس التعاون الخليجي
# 9  دول مجلس التعاون الخليجي
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                  القيمة بالاف ريال
# 2                                                NaN
# 3                                                NaN
# 4                                              الوصف
# 5                                                NaN
# 6  لحوم وأحشاء وأطراف دجاج (جالوس دوميستكوس) غير ...
# 7                            غيره من حليب ، غير محلى
# 8                                          لبن زبادى
# 9       أجبان مصنعة أو مطبوخة، غير مبشورة ولا مسحوقة
#
# ...

# %%
Exports_commodityGroup.drop(['Unnamed: 0', 'Unnamed: 1', 'الصادرات حسب مجموعات الدول و أهم الاصناف', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 
'Unnamed: 7', 'Unnamed: 8', 'R'], axis= 1, inplace=True)
Exports_commodityGroup.drop([0,1,2,3,4,5], axis=0, inplace=True)
Exports_commodityGroup.rename(columns={'Unnamed: 9': 'Quantity/Units', 'Unnamed: 10': 'Weight(Tons)', 'Unnamed: 11': 'Value(1000 SAR)',
'Unnamed: 12' : 'Commodity Code', 'Unnamed: 13' : 'Commodity', 'Unnamed: 14': 'Country Group'}, inplace=True)

# %%
Exports_commodityGroup.to_csv('Cleaned_data/Trading2020_3-7_clean.csv')

# %%
Exports_commodityGroup
# Out:
#     Quantity/Units Weight(Tons) Value(1000 SAR) Commodity Code  \
# 503              0        1.126        5033.246       85381000
# 504              0       79.082        2734.068       86040000
# 505              0      258.684       21610.102       87163990
# 506              0       19.064       20952.424       88033000
# 507              0        1.105         1988.33       88052900
# 508              0       23.135        3492.275       90158000
# 509              0        4.799        3499.734       90159000
# 510              0        3.249        3016.643       90183190
# 511            552         0.07       11728.639       91011100
# 512            240        0.024        2622.784       91012100
# 513            451        0.091        7237.034       91021100
# 514             36        0.026        3626.034       91051100
# 515              0     5609.023       68135.859       99999999
# 516              0      841.748        3886.262       39011000
# ...

# %% [markdown]
# Count not defined in Country Group = 7

# %%
Exports_commodityGroup.isnull().sum()
# Out:
# Quantity/Units     0
# Weight(Tons)       0
# Value(1000 SAR)    0
# Commodity Code     0
# Commodity          0
# Country Group      0
# dtype: int64

# %% [markdown]
# # Tradin20
#
# ## Sheet 1.1
# - Oil Vs. Non-oil Exports & Imports percentage
# - 2011 - 2020

# %%
Trading_Oil_non_Oil0 = pd.read_excel ('Data/Trading20.xlsx', sheet_name='1.1')
Trading_Oil_non_Oil0.to_csv("Cleaned_data/Trading20_1-1.csv", sep=",")

# %%
Trading_Oil_non_Oil = pd.DataFrame(Trading_Oil_non_Oil0)

# %%
Trading_Oil_non_Oil
# Out:
#                            Unnamed: 0                          Unnamed: 1  \
# 0                                 NaN                                 NaN
# 1   الصادرات البترولية وغير البترولية                                 NaN
# 2             Oil and Non-oil Exports                                 NaN
# 3                               السنة  Oil Exports  /  الصادرات البترولية
# 4                                 NaN                          مليون ريال
# 5                                Year                      Million Riyals
# 6                                2011                      1191052.099035
# 7                                2012                      1265550.609938
# 8                                2013                      1207080.083757
# 9                                2014                      1067091.641953
# 10                               2015                       573411.984959
# 11                               2016                       510729.487152
# ...

# %%
Trading_Oil_non_Oil.drop(['Unnamed: 5','الفهرس / Index'], axis=1, inplace=True)
Trading_Oil_non_Oil.drop([0,1,2,3,4,5], axis=0, inplace=True)

# %%
Trading_Oil_non_Oil.rename(columns={'Unnamed: 0': 'Year', 'Unnamed: 1' : 'Oil Exports Value(Millions SAR)', 
'Unnamed: 2' : 'Oil Percentage of Total Exports', 'Unnamed: 3' : 'Non-oil Exports Value(millions SAR)', 
'Unnamed: 4' : 'Non-oil Percentage of Total Exports'}, inplace=True)

# %%
Trading_Oil_non_Oil
# Out:
#     Year Oil Exports Value(Millions SAR) Oil Percentage of Total Exports  \
# 6   2011                  1191052.099035                       87.089414
# 7   2012                  1265550.609938                       86.889717
# 8   2013                  1207080.083757                        85.63747
# 9   2014                  1067091.641953                       83.098959
# 10  2015                   573411.984959                       75.121469
# 11  2016                   510729.487152                       74.188322
# 12  2017                   638402.283358                       76.741993
# 13  2018                   868442.402326                       78.670352
# 14  2019                   751828.128682                       76.637987
# 15  2020                    447599.22526                       68.655246
#
#    Non-oil Exports Value(millions SAR) Non-oil Percentage of Total Exports
# 6                        176567.731649                           12.910586
# ...

# %%
# Yess, 2020 matches the overall exports in Trading2020 file
447599.22526 + 204352.737425
# Out:
# 651951.9626849999

# %%
Trading_Oil_non_Oil.to_csv('Cleaned_data/Trading20_1-1_clean.csv')

# %%
x= Trading_Oil_non_Oil['Year']
y= Trading_Oil_non_Oil['Oil Percentage of Total Exports']
z= Trading_Oil_non_Oil['Non-oil Percentage of Total Exports']
plt.figure(figsize = [10,6])
plt.bar(x, y, 0.5, label= 'Oil Percentage of Total Exports')
plt.bar(x, z, 0.4, bottom= y, label= 'Non-oil Percentage of Total Exports')
plt.title('Oil Vs. Non-Oil Exports Percentage from 2011 - 2020', fontsize= 17)
plt.xlabel('Year',fontsize= 15)
plt.xticks(fontsize= 13)
plt.yticks(fontsize= 13)
plt.ylabel('Percentage %', fontsize= 12)
plt.legend(loc= 'best', fontsize= 12)
plt.show()

# %% [markdown]
# ggplot would be much more informative

# %% [markdown]
# ## Sheet 1.2
# Exports by section 2018-2020. Only values, no weights

# %%
Exports_bysection0 = pd.read_excel ('Data/Trading20.xlsx', sheet_name='1.2')
Exports_bysection0.to_csv("Cleaned_data/Trading20_1-2.csv", sep=",")

# %%
Exports_bysection= pd.DataFrame(Exports_bysection0)

# %%
Exports_bysection
# Out:
#               Unnamed: 0                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1   الصادرات حسب الاقسام                                                NaN
# 2     Exports by Section                                                NaN
# 3              رقم القسم                                          وصف القسم
# 4                    NaN                                                NaN
# 5                      1                الحيوانات الحية والمنتجات الحيوانية
# 6                      2                                      منتجات نباتية
# 7                      3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 8                      4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
# 9                      5                                  المنتجات المعدنية
# 10                     6             منتجات الصناعات الكيماوية وما يتصل بها
# ...

# %%
Exports_bysection.rename(columns={'Unnamed: 2' : '2018 Value(millions in SAR)',
	'Unnamed: 3' : '2019 Value(millions in SAR)', 'Unnamed: 4' : '2020 Value(millions in SAR)', 
    'Unnamed: 5' : 'Section Description', 'Unnamed: 6' : 'Section Number'}, inplace=True)

# %%
Exports_bysection.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 7', 'الفهرس / Index'], axis=1, inplace=True)
Exports_bysection.drop([0,1,2,3,4,26], axis=0, inplace=True)

# %%
Exports_bysection
# Out:
#    2018 Value(millions in SAR)  2019 Value(millions in SAR)  \
# 5                  6057.512578                  5687.233568
# 6                  1440.949608                  1563.584641
# 7                   819.818876                   849.966497
# 8                  5470.373403                  5782.133899
# 9                872029.853072                754960.758584
# 10                75455.289785                 69551.508281
# 11                79667.031342                 72833.580298
# 12                  270.407456                   280.720176
# 13                  311.069498                   364.556581
# 14                 2777.208284                  2556.065300
# 15                 2028.252427                  1873.730113
# 16                   80.914109                    81.256700
# 17                 2161.095034                  2058.660909
# 18                 3613.703033                  5739.889889
# 19                20645.345694                 16868.946345
# ...

# %%
Exports_bysection['2018 Value(millions in SAR)'] = Exports_bysection['2018 Value(millions in SAR)'].astype(float)
Exports_bysection['Section Number'] = Exports_bysection['Section Number'].astype(int)

# %%
Exports_bysection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 5 to 25
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   2018 Value(millions in SAR)  21 non-null     float64
#  1   2019 Value(millions in SAR)  21 non-null     float64
#  2   2020 Value(millions in SAR)  21 non-null     float64
#  3   Section Description          21 non-null     object
#  4   Section Number               21 non-null     int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1008.0+ bytes

# %%
Exports_bysection.to_csv('Cleaned_data/Trading20_1-2_clean.csv')

# %%
Exports_bysection[['2018 Value(millions in SAR)', '2019 Value(millions in SAR)', '2020 Value(millions in SAR)']].max()
# Out:
# 2018 Value(millions in SAR)    872029.853072
# 2019 Value(millions in SAR)    754960.758584
# 2020 Value(millions in SAR)     451092.77604
# dtype: object

# %%
Exports_bysection[['2018 Value(millions in SAR)', '2019 Value(millions in SAR)', '2020 Value(millions in SAR)']].min()
# Out:
# 2018 Value(millions in SAR)    80.914109
# 2019 Value(millions in SAR)      81.2567
# 2020 Value(millions in SAR)    51.349993
# dtype: object

# %%
Exports_bysection[['2018 Value(millions in SAR)', '2019 Value(millions in SAR)', '2020 Value(millions in SAR)']].sum()
# Out:
# 2018 Value(millions in SAR)    1103900.485991
# 2019 Value(millions in SAR)     981012.363319
# 2020 Value(millions in SAR)     651951.962685
# dtype: object

# %% [markdown]
# ## Sheet 2.1
# Imports by section 2018-2020. Only values, no weights

# %%
Imports_bysection0 = pd.read_excel ('Data/Trading20.xlsx', sheet_name='2.1')
Imports_bysection0.to_csv("Cleaned_data/Trading20_2-1.csv", sep=",")

# %%
Imports_bysection= pd.DataFrame(Imports_bysection0)

# %%
Imports_bysection
# Out:
#               Unnamed: 0                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1   الواردات حسب الاقسام                                                NaN
# 2     Imports by Section                                                NaN
# 3              رقم القسم                                          وصف القسم
# 4                    NaN                                                NaN
# 5                      1                الحيوانات الحية والمنتجات الحيوانية
# 6                      2                                      منتجات نباتية
# 7                      3  شحوم ودهون وزيوت حيوانية أو نباتية ومنتجات تفك...
# 8                      4  منتجات صناعة الأغذية؛ مشروبات؛ سوائل كحولية وخ...
# 9                      5                                  المنتجات المعدنية
# 10                     6             منتجات الصناعات الكيماوية وما يتصل بها
# ...

# %%
Imports_bysection.rename(columns={'Unnamed: 2' : '2018 Value(millions in SAR)',
	'Unnamed: 3' : '2019 Value(millions in SAR)', 'Unnamed: 4' : '2020 Value(millions in SAR)', 
    'Unnamed: 5' : 'Section Description', 'Unnamed: 6' : 'Section Number'}, inplace=True)

# %%
Imports_bysection.drop([0,1,2,3,4,26], axis=0, inplace=True)
Imports_bysection.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 7', 'الفهرس / Index'], axis=1, inplace=True)

# %%
Imports_bysection
# Out:
#    2018 Value(millions in SAR)  2019 Value(millions in SAR)  \
# 5                 18095.450548                 19507.619134
# 6                 32996.027181                 31123.980544
# 7                  3521.849209                  3338.453922
# 8                 25635.233829                 27399.318015
# 9                 21090.437514                 18021.236913
# 10                51715.771619                 53854.494181
# 11                17486.718316                 20567.953322
# 12                 1872.681936                  2295.584415
# 13                 4271.516713                  4750.736646
# 14                 7260.801908                  7150.673740
# 15                18115.072085                 22732.145945
# 16                 3341.486274                  4099.506056
# 17                  6930.86817                  7631.411464
# 18                15725.216602                 13506.827734
# 19                43987.942217                 48895.921336
# ...

# %%
Imports_bysection['Section Number']= Imports_bysection['Section Number'].astype(int)

# %%
Imports_bysection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 5 to 25
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   2018 Value(millions in SAR)  21 non-null     object
#  1   2019 Value(millions in SAR)  21 non-null     float64
#  2   2020 Value(millions in SAR)  21 non-null     float64
#  3   Section Description          21 non-null     object
#  4   Section Number               21 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1008.0+ bytes

# %%
Imports_bysection.to_csv("Cleaned_data/Trading20_2-1_clean.csv")

# %%
Imports_bysection[['2018 Value(millions in SAR)', '2019 Value(millions in SAR)', '2020 Value(millions in SAR)']].max()
# Out:
# 2018 Value(millions in SAR)    111167.035485
# 2019 Value(millions in SAR)    120291.009235
# 2020 Value(millions in SAR)    109093.738466
# dtype: object

# %%
Imports_bysection[['2018 Value(millions in SAR)', '2019 Value(millions in SAR)', '2020 Value(millions in SAR)']].min()
# Out:
# 2018 Value(millions in SAR)    1872.681936
# 2019 Value(millions in SAR)    2295.584415
# 2020 Value(millions in SAR)    1650.055971
# dtype: object
